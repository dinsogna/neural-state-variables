# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
folder = 'base/3'

ids = np.load(f'{folder}/ids.npy')
latent = np.load(f'{folder}/latent.npy')
recon_latent = np.load(f'{folder}/reconstructed_latent.npy')
refine_latent = np.load(f'{folder}/refine_latent.npy')

# %%
var1 = refine_latent[0:57, 0]
var2 = refine_latent[0:57, 1]

# %%
plt.plot(var1)
plt.plot(var2)
plt.show()

# %%
plt.close()

# %%
video = 3
var1 = refine_latent[57 * (video - 1) : 57 * video, 0]
var2 = refine_latent[57 * (video - 1):57 * video, 1]

# %%
fig, axs = plt.subplots(2, 2)

for i in range(2):
    for j in range(2):
        video = 31*i + 17*j + 13
        var1 = refine_latent[57 * (video - 1) : 57 * video, 0]
        var2 = refine_latent[57 * (video - 1):57 * video, 1]
        axs[i,j].plot(var1)
        axs[i,j].plot(var2)
        # axs[i,j].plot(var2 - var1)
        # axs[i,j].plot(var1 - var2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.close()
# Out:
# array(['887_0.png', '887_1.png', '887_2.png', '887_3.png', '887_4.png',
#        '887_5.png', '887_6.png', '887_7.png', '887_8.png', '887_9.png',
#        '887_10.png', '887_11.png', '887_12.png', '887_13.png',
#        '887_14.png', '887_15.png', '887_16.png', '887_17.png',
#        '887_18.png', '887_19.png', '887_20.png', '887_21.png',
#        '887_22.png', '887_23.png', '887_24.png', '887_25.png',
#        '887_26.png', '887_27.png', '887_28.png', '887_29.png',
#        '887_30.png', '887_31.png', '887_32.png', '887_33.png',
#        '887_34.png', '887_35.png', '887_36.png', '887_37.png',
#        '887_38.png', '887_39.png', '887_40.png', '887_41.png',
#        '887_42.png', '887_43.png', '887_44.png', '887_45.png',
#        '887_46.png', '887_47.png', '887_48.png', '887_49.png',
#        '887_50.png', '887_51.png', '887_52.png', '887_53.png',
#        '887_54.png', '887_55.png', '887_56.png'], dtype='<U11')
